# %% [markdown]
# **Aluno:** Felipe Bizzo da Silva -------------------- **RA:** 155351-8

# %% [markdown]
# # Enunciado 9.10
# Utilizando como base de dados do Prob. 9.8. Calcule o rendimento térmico do ciclo e o título do vapor na seção de descarga da turbina para pressões de saída iguais a 5kPa, 10kPa, 50kPa e 100kPa. Faça também um gráfico de rendimento térmico em função da pressão de saída da turbina.

# %%
# !pip install pyromat
import pyromat as pm
import matplotlib.pyplot as plt

pm.config["unit_pressure"] = "kPa"
pm.config["def_p"] = 100

mp_water = pm.get("mp.H2O")

resultado_10, resultado_11, resultado_12 = [], [], []

# %%
def rendimento_titulo (p1, p2, T2):
  T1 = mp_water.Ts(p=p1)[0]
  print(f"T1 = {round(float(T1),1)} ºC")

  s1 = mp_water.ss(p=p1)[0]
  s2= s1
  v = 1/mp_water.ds(p=p1)[0]

  w_p = v*(p2-p1)
  print(f"Trabalho requerido na bomba: {round(float(w_p),1)} kJ/kg")

  h1 = mp_water.hs(p=p1)[0]
  print(f"h1 = {round(float(h1),1)} kJ/kg")

  h2 = h1+w_p
  print(f"h2 = {round(float(h2),1)} kJ/kg")

  p3 = p2
  s3 = mp_water.ss(p=p3)[1]
  T3, x3 = mp_water.T_s(s=s3,p=p3, quality=True)
  s3dash = mp_water.ss(p=p3)[0]
  T3dash = T3
  h3 = mp_water.hs(p=p3)[1]
  print(f"h3 = {round(float(h3),1)} kJ/kg")
  print(f"s3 = {round(float(s3),1)} kJ/kg K")
  print(f"T3 = {round(float(T3),1)} ºC")
  print(f"Qualidade do vapor na saida da caldeira x3: {round(float(x3),4)}")

  q_H = h3-h2
  print(f"Calor gerado na caldeira: {round(float(q_H),1)} kJ/kg")

  p4 = p1
  s4 = s3
  T4, x4 = mp_water.T_s(s=s4,p=p4, quality=True)
  print(f"T4 = {round(float(T4),1)} ºC")

  h4 = mp_water.h(p=p4,x=x4)
  print(f"h4 = {round(float(h4),1)} kJ/kg")
  print(f"s4 = {round(float(s4),1)} kJ/kg K")

  w_t = h3-h4
  print(f"Qualidade do vapor na saída da turbina x4: {round(float(x4),4)}")
  print(f"Trabalho gerado pela turbina: {round(float(w_t),1)} kJ/kg")

  q_L = h4-h1
  print(f"Calor rejeitado pelo condensador: {round(float(q_L),1)} kJ/kg")

  eta_th = (w_t-w_p)/q_H*100
  print(f"A eficiência térmica é: {round(float(eta_th),1)}%")

  return eta_th

# %%
def graph_config(x, y, title):
  plt.xlabel(x, size = 16,)
  plt.ylabel(y, size = 16)
  plt.title(title, 
            fontdict={'family': 'serif', 
                      'color' : 'darkblue',
                      'weight': 'bold',
                      'size': 18})
  plt.grid(True)
  plt.show()

# %% [markdown]
# ### Calcule o rendimento térmico do ciclo e o título na descarga da turbina para pressões de saída iguais a:
# **Pressão de saída igual a P = 5kPa**

# %%
resultado_10.append(rendimento_titulo(p1 = 5, p2 = 3500, T2 = 400))
# Out:
# T1 = 306.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 137.7 kJ/kg
# h2 = 141.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2661.4 kJ/kg
# T4 = 306.0 ºC
# h4 = 1866.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7134
# Trabalho gerado pela turbina: 936.4 kJ/kg
# Calor rejeitado pelo condensador: 1728.5 kJ/kg
# A eficiência térmica é: 35.1%

# %% [markdown]
# **Pressão de saída igual a P = 10kPa**

# %%
resultado_10.append(rendimento_titulo(p1 = 10, p2 = 3500, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 195.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2607.4 kJ/kg
# T4 = 319.0 ºC
# h4 = 1938.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7301
# Trabalho gerado pela turbina: 864.5 kJ/kg
# Calor rejeitado pelo condensador: 1746.4 kJ/kg
# A eficiência térmica é: 33.0%

# %% [markdown]
# **Pressão de saída igual a P = 50kPa**

# %%
resultado_10.append(rendimento_titulo(p1 = 50, p2 = 3500, T2 = 400))
# Out:
# T1 = 354.5 ºC
# Trabalho requerido na bomba: 3.6 kJ/kg
# h1 = 340.5 kJ/kg
# h2 = 344.1 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2458.6 kJ/kg
# T4 = 354.5 ºC
# h4 = 2124.6 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7741
# Trabalho gerado pela turbina: 678.0 kJ/kg
# Calor rejeitado pelo condensador: 1784.1 kJ/kg
# A eficiência térmica é: 27.4%

# %% [markdown]
# **Pressão de saída igual a P = 100kPa**

# %%
resultado_10.append(rendimento_titulo(p1 = 100, p2 = 3500, T2 = 400))
# Out:
# T1 = 372.8 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 417.5 kJ/kg
# h2 = 421.1 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2381.6 kJ/kg
# T4 = 372.8 ºC
# h4 = 2214.8 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7962
# Trabalho gerado pela turbina: 587.9 kJ/kg
# Calor rejeitado pelo condensador: 1797.3 kJ/kg
# A eficiência térmica é: 24.5%

# %%
pressões_10 = [5,10,50,100]

# %%
plt.plot(resultado_10, pressões_10)
graph_config("Rendimento", "Pressão", "Ex. 9.10")

# %% [markdown]
# # Enunciado 9.11
# Calcule o rendimento e o título na seção de descarga da turbina para pressões de entrada iguais a 1MPa, 3,5MPa, 6MPa e 10MPa. Faça também um gráfico de rendimento térmico em função da pressão de saída da turbina.

# %% [markdown]
# **Pressão de entrada igual a P = 1MPa**

# %%
resultado_11.append(rendimento_titulo(p1 = 10, p2 = 1000, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 1.0 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 192.8 kJ/kg
# h3 = 2777.1 kJ/kg
# s3 = 6.6 kJ/kg K
# T3 = 453.0 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2584.3 kJ/kg
# T4 = 319.0 ºC
# h4 = 2085.1 kJ/kg
# s4 = 6.6 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7915
# Trabalho gerado pela turbina: 692.0 kJ/kg
# Calor rejeitado pelo condensador: 1893.3 kJ/kg
# A eficiência térmica é: 26.7%

# %% [markdown]
# **Pressão de entrada igual a P = 3,5MPa**

# %%
resultado_11.append(rendimento_titulo(p1 = 10, p2 = 3500, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 195.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2607.4 kJ/kg
# T4 = 319.0 ºC
# h4 = 1938.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7301
# Trabalho gerado pela turbina: 864.5 kJ/kg
# Calor rejeitado pelo condensador: 1746.4 kJ/kg
# A eficiência térmica é: 33.0%

# %% [markdown]
# **Pressão de entrada igual a P = 6MPa**

# %%
resultado_11.append(rendimento_titulo(p1 = 10, p2 = 6000, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 6.1 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 197.8 kJ/kg
# h3 = 2784.6 kJ/kg
# s3 = 5.9 kJ/kg K
# T3 = 548.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2586.8 kJ/kg
# T4 = 319.0 ºC
# h4 = 1863.5 kJ/kg
# s4 = 5.9 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.6988
# Trabalho gerado pela turbina: 921.2 kJ/kg
# Calor rejeitado pelo condensador: 1671.7 kJ/kg
# A eficiência térmica é: 35.4%

# %% [markdown]
# **Pressão de entrada igual a P = 10MPa**

# %%
resultado_11.append(rendimento_titulo(p1 = 10, p2 = 10000, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 10.1 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 201.9 kJ/kg
# h3 = 2725.5 kJ/kg
# s3 = 5.6 kJ/kg K
# T3 = 584.1 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2523.6 kJ/kg
# T4 = 319.0 ºC
# h4 = 1776.0 kJ/kg
# s4 = 5.6 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.6623
# Trabalho gerado pela turbina: 949.5 kJ/kg
# Calor rejeitado pelo condensador: 1584.2 kJ/kg
# A eficiência térmica é: 37.2%

# %%
pressões_11 = [1,3.5,6,10]

# %%
plt.plot(resultado_11, pressões_11)
graph_config("Rendimento", "Pressão", "Ex. 9.11")

# %% [markdown]
# # Enunciado 9.12
# Calcule o rendimento e o título na seção de descarga da turbina para as temperaturas de entrada 400, 500 e 800. Faça também um gráfico de rendimento térmico em função da temperatura.

# %% [markdown]
# **Temperatura de entrada na turbina igual a 400ºC**

# %%
resultado_12.append(rendimento_titulo(p1 = 10, p2 = 3500, T2 = 400))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 195.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2607.4 kJ/kg
# T4 = 319.0 ºC
# h4 = 1938.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7301
# Trabalho gerado pela turbina: 864.5 kJ/kg
# Calor rejeitado pelo condensador: 1746.4 kJ/kg
# A eficiência térmica é: 33.0%

# %% [markdown]
# **Temperatura de entrada na turbina igual a 500ºC**

# %%
resultado_12.append(rendimento_titulo(p1 = 10, p2 = 3500, T2 = 500))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 195.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2607.4 kJ/kg
# T4 = 319.0 ºC
# h4 = 1938.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7301
# Trabalho gerado pela turbina: 864.5 kJ/kg
# Calor rejeitado pelo condensador: 1746.4 kJ/kg
# A eficiência térmica é: 33.0%

# %% [markdown]
# **Temperatura de entrada na turbina igual a 800ºC**

# %%
resultado_12.append(rendimento_titulo(p1 = 10, p2 = 3500, T2 = 800))
# Out:
# T1 = 319.0 ºC
# Trabalho requerido na bomba: 3.5 kJ/kg
# h1 = 191.8 kJ/kg
# h2 = 195.3 kJ/kg
# h3 = 2802.7 kJ/kg
# s3 = 6.1 kJ/kg K
# T3 = 515.7 ºC
# Qualidade do vapor na saida da caldeira x3: 1.0
# Calor gerado na caldeira: 2607.4 kJ/kg
# T4 = 319.0 ºC
# h4 = 1938.2 kJ/kg
# s4 = 6.1 kJ/kg K
# Qualidade do vapor na saída da turbina x4: 0.7301
# Trabalho gerado pela turbina: 864.5 kJ/kg
# Calor rejeitado pelo condensador: 1746.4 kJ/kg
# A eficiência térmica é: 33.0%

# %%
temperaturas_12 = [400,500,800]

# %%
plt.plot(resultado_12, temperaturas_12)
graph_config("Rendimento", "Temperatura", "Ex. 9.12")
